# %% [markdown]
# # Visualization Notebook
#
# This notebook is for creating and displaying visualizations for the twitter-climate-sentiment-pipeline project. Add your plotting code and visual outputs below.
